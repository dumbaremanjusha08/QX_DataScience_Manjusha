# %%
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading https://files.pythonhosted.org/packages/54/5f/e1b2d83b808f978f51b7ce109315154da3a3d4151aa59686002681f2e109/tensorflow-2.0.0-cp37-cp37m-win_amd64.whl (48.1MB)
# Collecting google-pasta>=0.1.6 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/d0/33/376510eb8d6246f3c30545f416b2263eee461e40940c2a4413c711bdf62d/google_pasta-0.1.7-py3-none-any.whl (52kB)
# Collecting astor>=0.6.0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/d1/4f/950dfae467b384fc96bc6469de25d832534f6b4441033c39f914efd13418/astor-0.8.0-py2.py3-none-any.whl
# Collecting tensorboard<2.1.0,>=2.0.0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/9b/a6/e8ffa4e2ddb216449d34cfcb825ebb38206bee5c4553d69e7bc8bc2c5d64/tensorboard-2.0.0-py3-none-any.whl (3.8MB)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in c:\users\sachin\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: keras-applications>=1.0.8 in c:\users\sachin\anaconda3\lib\site-packages (from tensorflow) (1.0.8)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in c:\users\sachin\anaconda3\lib\site-packages (from tensorflow) (1.16.4)
# Collecting opt-einsum>=2.3.2 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/b8/83/755bd5324777875e9dff19c2e59daec837d0378c09196634524a3d7269ac/opt_einsum-3.1.0.tar.gz (69kB)
# Collecting absl-py>=0.7.0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/3c/0d/7cbf64cac3f93617a2b6b079c0182e4a83a3e7a8964d3b0cc3d9758ba002/absl-py-0.8.0.tar.gz (102kB)
# Collecting protobuf>=3.6.1 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/92/4e/a90c0000a8dee84c3717ccf86eaafd892f342b0aa242d3cb34d62b1b19dd/protobuf-3.9.2-cp37-cp37m-win_amd64.whl (1.0MB)
# Collecting gast==0.2.2 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Collecting grpcio>=1.8.6 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/9a/28/18db422098a56a01bb753611a718b148963393f22efe9089711fb93440a3/grpcio-1.24.0-cp37-cp37m-win_amd64.whl (1.6MB)
# Collecting tensorflow-estimator<2.1.0,>=2.0.0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/95/00/5e6cdf86190a70d7382d320b2b04e4ff0f8191a37d90a422a2f8ff0705bb/tensorflow_estimator-2.0.0-py2.py3-none-any.whl (449kB)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/8a/48/a76be51647d0eb9f10e2a4511bf3ffb8cc1e6b14e9e4fab46173aa79f981/termcolor-1.1.0.tar.gz
# Requirement already satisfied: six>=1.10.0 in c:\users\sachin\anaconda3\lib\site-packages (from tensorflow) (1.12.0)
# Requirement already satisfied: wheel>=0.26 in c:\users\sachin\anaconda3\lib\site-packages (from tensorflow) (0.33.4)
# Requirement already satisfied: wrapt>=1.11.1 in c:\users\sachin\anaconda3\lib\site-packages (from tensorflow) (1.11.2)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\sachin\anaconda3\lib\site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow) (0.15.4)
# Collecting markdown>=2.6.8 (from tensorboard<2.1.0,>=2.0.0->tensorflow)
#   Downloading https://files.pythonhosted.org/packages/c0/4e/fd492e91abdc2d2fcb70ef453064d980688762079397f779758e055f6575/Markdown-3.1.1-py2.py3-none-any.whl (87kB)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\sachin\anaconda3\lib\site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow) (41.0.1)
# Requirement already satisfied: h5py in c:\users\sachin\anaconda3\lib\site-packages (from keras-applications>=1.0.8->tensorflow) (2.9.0)
# Building wheels for collected packages: opt-einsum, absl-py, gast, termcolor
#   Building wheel for opt-einsum (setup.py): started
#   Building wheel for opt-einsum (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\Sachin\AppData\Local\pip\Cache\wheels\2c\b1\94\43d03e130b929aae7ba3f8d15cbd7bc0d1cb5bb38a5c721833
#   Building wheel for absl-py (setup.py): started
#   Building wheel for absl-py (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\Sachin\AppData\Local\pip\Cache\wheels\9a\1e\7a\456008eb5e47fd5de792c6139df6d5b3d5f71d51c6a0b94799
#   Building wheel for gast (setup.py): started
#   Building wheel for gast (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\Sachin\AppData\Local\pip\Cache\wheels\5c\2e\7e\a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\Sachin\AppData\Local\pip\Cache\wheels\7c\06\54\bc84598ba1daf8f970247f550b175aaaee85f68b4b0c5ab2c6
# Successfully built opt-einsum absl-py gast termcolor
# Installing collected packages: google-pasta, astor, grpcio, protobuf, absl-py, markdown, tensorboard, opt-einsum, gast, tensorflow-estimator, termcolor, tensorflow
# Successfully installed absl-py-0.8.0 astor-0.8.0 gast-0.2.2 google-pasta-0.1.7 grpcio-1.24.0 markdown-3.1.1 opt-einsum-3.1.0 protobuf-3.9.2 tensorboard-2.0.0 tensorflow-2.0.0 tensorflow-estimator-2.0.0 termcolor-1.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
import tensorflow as tf
import numpy as np

# %%
from keras.models import Sequential
from keras.layers import GRU, Dense
from keras.layers import LSTM
from keras  import callbacks
from keras import optimizers
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv('data/international-airline-passengers.csv', index_col='Month')
print(df.head())
df.plot()
# Out:
#          Passengers
# Month
# 1949-01       112.0
# 1949-02       118.0
# 1949-03       132.0
# 1949-04       129.0
# 1949-05       121.0

# %%
columns_to_keep = ['Passengers']
df = df[columns_to_keep]
df['Passengers'] = df['Passengers'].apply(lambda x: x*1000)
df.index.names = ['Month']
df.sort_index(inplace=True)
print('Total rows: {}'.format(len(df)))
df.head()
# Out:
# Total rows: 146
#          Passengers
# Month
# 1949-01    112000.0
# 1949-02    118000.0
# 1949-03    132000.0
# 1949-04    129000.0
# 1949-05    121000.0

# %%
df.describe()
# Out:
#           Passengers
# count     144.000000
# mean   280298.611111
# std    119966.316943
# min    104000.000000
# 25%    180000.000000
# 50%    265500.000000
# 75%    360500.000000
# max    622000.000000

# %%
df.plot()

# %%
df.isnull().sum()
# Out:
# Passengers    2
# dtype: int64

# %%
null_columns=df.columns[df.isnull().any()]
df[null_columns].isnull().sum()
# Out:
# Passengers    2
# dtype: int64

# %%
df
# Out:
#                                                     Passengers
# Month
# 1949-01                                               112000.0
# 1949-02                                               118000.0
# 1949-03                                               132000.0
# 1949-04                                               129000.0
# 1949-05                                               121000.0
# 1949-06                                               135000.0
# 1949-07                                               148000.0
# 1949-08                                               148000.0
# 1949-09                                               136000.0
# 1949-10                                               119000.0
# 1949-11                                               104000.0
# 1949-12                                               118000.0
# 1950-01                                               115000.0
# 1950-02                                               126000.0
# 1950-03                                               141000.0
# 1950-04                                               135000.0
# 1950-05                                               125000.0
# 1950-06                                               149000.0
# 1950-07                                               170000.0
# 1950-08                                               170000.0
# 1950-09                                               158000.0
# 1950-10                                               133000.0
# 1950-11                                               114000.0
# 1950-12                                               140000.0
# 1951-01                                               145000.0
# 1951-02                                               150000.0
# 1951-03                                               178000.0
# 1951-04                                               163000.0
# 1951-05                                               172000.0
# 1951-06                                               178000.0
# ...                                                        ...
# 1958-09                                               404000.0
# 1958-10                                               359000.0
# 1958-11                                               310000.0
# 1958-12                                               337000.0
# 1959-01                                               360000.0
# 1959-02                                               342000.0
# 1959-03                                               406000.0
# 1959-04                                               396000.0
# 1959-05                                               420000.0
# 1959-06                                               472000.0
# 1959-07                                               548000.0
# 1959-08                                               559000.0
# 1959-09                                               463000.0
# 1959-10                                               407000.0
# 1959-11                                               362000.0
# 1959-12                                               405000.0
# 1960-01                                               417000.0
# 1960-02                                               391000.0
# 1960-03                                               419000.0
# 1960-04                                               461000.0
# 1960-05                                               472000.0
# 1960-06                                               535000.0
# 1960-07                                               622000.0
# 1960-08                                               606000.0
# 1960-09                                               508000.0
# 1960-10                                               461000.0
# 1960-11                                               390000.0
# 1960-12                                               432000.0
# International airline passengers: monthly total...         NaN
# NaN                                                        NaN
#
# [146 rows x 1 columns]

# %%
print(df[df.isnull().any(axis=1)][null_columns].head())
# Out:
#                                                     Passengers
# Month
# International airline passengers: monthly total...         NaN
# NaN                                                        NaN

# %%
df.dropna(inplace=True)

# %%
print(df[df.isnull().any(axis=1)][null_columns].head())
# Out:
# Empty DataFrame
# Columns: [Passengers]
# Index: []

# %%
df.isnull().sum()
# Out:
# Passengers    0
# dtype: int64

# %%
df.hist(bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000010A8EA90>]],
#       dtype=object)

# %%
len(df[df['Passengers'] == 0])
# Out:
# 0

# %%
print('Min', np.min(df))
print('Max', np.max(df))
# Out:
# Min Passengers    104000.0
# dtype: float64
# Max Passengers    622000.0
# dtype: float64

# %%
dataset = df.astype('float32')

# %%
dataset
# Out:
#          Passengers
# Month
# 1949-01    112000.0
# 1949-02    118000.0
# 1949-03    132000.0
# 1949-04    129000.0
# 1949-05    121000.0
# 1949-06    135000.0
# 1949-07    148000.0
# 1949-08    148000.0
# 1949-09    136000.0
# 1949-10    119000.0
# 1949-11    104000.0
# 1949-12    118000.0
# 1950-01    115000.0
# 1950-02    126000.0
# 1950-03    141000.0
# 1950-04    135000.0
# 1950-05    125000.0
# 1950-06    149000.0
# 1950-07    170000.0
# 1950-08    170000.0
# 1950-09    158000.0
# 1950-10    133000.0
# 1950-11    114000.0
# 1950-12    140000.0
# 1951-01    145000.0
# 1951-02    150000.0
# 1951-03    178000.0
# 1951-04    163000.0
# 1951-05    172000.0
# 1951-06    178000.0
# ...             ...
# 1958-07    491000.0
# 1958-08    505000.0
# 1958-09    404000.0
# 1958-10    359000.0
# 1958-11    310000.0
# 1958-12    337000.0
# 1959-01    360000.0
# 1959-02    342000.0
# 1959-03    406000.0
# 1959-04    396000.0
# 1959-05    420000.0
# 1959-06    472000.0
# 1959-07    548000.0
# 1959-08    559000.0
# 1959-09    463000.0
# 1959-10    407000.0
# 1959-11    362000.0
# 1959-12    405000.0
# 1960-01    417000.0
# 1960-02    391000.0
# 1960-03    419000.0
# 1960-04    461000.0
# 1960-05    472000.0
# 1960-06    535000.0
# 1960-07    622000.0
# 1960-08    606000.0
# 1960-09    508000.0
# 1960-10    461000.0
# 1960-11    390000.0
# 1960-12    432000.0
#
# [144 rows x 1 columns]

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(dataset)

# %%
scaled
# Out:
# array([[0.01544402],
#        [0.02702703],
#        [0.05405405],
#        [0.04826255],
#        [0.03281853],
#        [0.05984556],
#        [0.08494208],
#        [0.08494208],
#        [0.06177606],
#        [0.02895753],
#        [0.        ],
#        [0.02702703],
#        [0.02123552],
#        [0.04247104],
#        [0.07142857],
#        [0.05984556],
#        [0.04054054],
#        [0.08687259],
#        [0.12741313],
#        [0.12741313],
#        [0.1042471 ],
#        [0.05598456],
#        [0.01930502],
#        [0.06949807],
#        [0.07915058],
#        [0.08880309],
#        [0.14285714],
#        [0.11389961],
#        [0.13127413],
#        [0.14285714],
#        [0.18339768],
#        [0.18339768],
#        [0.15444015],
#        [0.11196911],
#        [0.08108108],
#        [0.11969112],
#        [0.12934363],
#        [0.14671815],
#        [0.17181467],
#        [0.14864865],
#        [0.15250965],
#        [0.22007722],
#        [0.24324324],
#        [0.26640927],
#        [0.2027027 ],
#        [0.16795367],
#        [0.13127413],
#        [0.17374517],
#        [0.17760618],
#        [0.17760618],
#        [0.25482625],
#        [0.25289575],
#        [0.24131274],
#        [0.26833977],
#        [0.30888031],
#        [0.32432432],
#        [0.25675676],
#        [0.20656371],
#        [0.14671815],
#        [0.18725869],
#        [0.19305019],
#        [0.16216216],
#        [0.25289575],
#        [0.23745174],
#        [0.25096525],
#        [0.30888031],
#        [0.38223938],
#        [0.36486486],
#        [0.2992278 ],
#        [0.24131274],
#        [0.19111969],
#        [0.24131274],
#        [0.26640927],
#        [0.24903475],
#        [0.31467181],
#        [0.31853282],
#        [0.32046332],
#        [0.40733591],
#        [0.5019305 ],
#        [0.46911197],
#        [0.4015444 ],
#        [0.32818533],
#        [0.25675676],
#        [0.33590734],
#        [0.34749035],
#        [0.33397683],
#        [0.41119691],
#        [0.4034749 ],
#        [0.41312741],
#        [0.52123552],
#        [0.5965251 ],
#        [0.58108108],
#        [0.48455598],
#        [0.38996139],
#        [0.32239382],
#        [0.38996139],
#        [0.40733591],
#        [0.38030888],
#        [0.48648649],
#        [0.47104247],
#        [0.48455598],
#        [0.61389961],
#        [0.6969112 ],
#        [0.7007722 ],
#        [0.57915058],
#        [0.46911197],
#        [0.38803089],
#        [0.44787645],
#        [0.45559846],
#        [0.41312741],
#        [0.4980695 ],
#        [0.47104247],
#        [0.5       ],
#        [0.63899614],
#        [0.74710425],
#        [0.77413127],
#        [0.57915058],
#        [0.49227799],
#        [0.3976834 ],
#        [0.44980695],
#        [0.49420849],
#        [0.45945946],
#        [0.58301158],
#        [0.56370656],
#        [0.61003861],
#        [0.71042471],
#        [0.85714286],
#        [0.87837838],
#        [0.69305019],
#        [0.58494208],
#        [0.4980695 ],
#        [0.58108108],
#        [0.6042471 ],
#        [0.55405405],
#        [0.60810811],
#        [0.68918919],
#        [0.71042471],
#        [0.83204633],
#        [1.        ],
#        [0.96911197],
#        [0.77992278],
#        [0.68918919],
#        [0.55212355],
#        [0.63320463]])

# %%
print('Min', np.min(scaled))
print('Max', np.max(scaled))
# Out:
# Min 0.0
# Max 1.0

# %%
print(scaled[:10])
#scaled.head(10)
# Out:
# [[0.01544402]
#  [0.02702703]
#  [0.05405405]
#  [0.04826255]
#  [0.03281853]
#  [0.05984556]
#  [0.08494208]
#  [0.08494208]
#  [0.06177606]
#  [0.02895753]]

# %%
train_size = int(len(scaled) * 0.70)
test_size = len(scaled - train_size)
train, test = scaled[0:train_size, :], scaled[train_size: len(scaled), :]
print('train: {}\ntest: {}'.format(len(train), len(test)))
# Out:
# train: 100
# test: 44

# %%
def create_dataset(dataset, look_back=1):
    print(len(dataset), look_back)
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        print(i)
        print('X {} to {}'.format(i, i+look_back))
        print(a)
        print('Y {}'.format(i + look_back))
        print(dataset[i + look_back, 0])
        dataset[i + look_back, 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
look_back = 1
X_train, y_train = create_dataset(train, look_back)
X_test, y_test = create_dataset(test, look_back)
# Out:
# 100 1
# 0
# X 0 to 1
# [0.01544402]
# Y 1
# 0.02702702702702703
# 1
# X 1 to 2
# [0.02702703]
# Y 2
# 0.05405405405405403
# 2
# X 2 to 3
# [0.05405405]
# Y 3
# 0.04826254826254825
# 3
# X 3 to 4
# [0.04826255]
# Y 4
# 0.03281853281853281
# 4
# X 4 to 5
# [0.03281853]
# Y 5
# 0.05984555984555981
# 5
# X 5 to 6
# [0.05984556]
# Y 6
# 0.08494208494208491
# 6
# X 6 to 7
# [0.08494208]
# Y 7
# 0.08494208494208491
# 7
# X 7 to 8
# [0.08494208]
# Y 8
# 0.06177606177606179
# 8
# X 8 to 9
# [0.06177606]
# Y 9
# 0.028957528957528955
# 9
# X 9 to 10
# [0.02895753]
# Y 10
# 0.0
# 10
# X 10 to 11
# [0.]
# Y 11
# 0.02702702702702703
# 11
# X 11 to 12
# [0.02702703]
# Y 12
# 0.02123552123552122
# 12
# X 12 to 13
# [0.02123552]
# Y 13
# 0.04247104247104247
# 13
# X 13 to 14
# [0.04247104]
# Y 14
# 0.07142857142857142
# 14
# X 14 to 15
# [0.07142857]
# Y 15
# 0.05984555984555981
# 15
# X 15 to 16
# [0.05984556]
# Y 16
# 0.04054054054054054
# 16
# X 16 to 17
# [0.04054054]
# Y 17
# 0.08687258687258684
# 17
# X 17 to 18
# [0.08687259]
# Y 18
# 0.1274131274131274
# 18
# X 18 to 19
# [0.12741313]
# Y 19
# 0.1274131274131274
# 19
# X 19 to 20
# [0.12741313]
# Y 20
# 0.10424710424710423
# 20
# X 20 to 21
# [0.1042471]
# Y 21
# 0.055984555984555956
# 21
# X 21 to 22
# [0.05598456]
# Y 22
# 0.019305019305019294
# 22
# X 22 to 23
# [0.01930502]
# Y 23
# 0.0694980694980695
# 23
# X 23 to 24
# [0.06949807]
# Y 24
# 0.07915057915057913
# 24
# X 24 to 25
# [0.07915058]
# Y 25
# 0.08880308880308882
# 25
# X 25 to 26
# [0.08880309]
# Y 26
# 0.14285714285714288
# 26
# X 26 to 27
# [0.14285714]
# Y 27
# 0.11389961389961387
# 27
# X 27 to 28
# [0.11389961]
# Y 28
# 0.13127413127413126
# 28
# X 28 to 29
# [0.13127413]
# Y 29
# 0.14285714285714288
# 29
# X 29 to 30
# [0.14285714]
# Y 30
# 0.1833976833976834
# 30
# X 30 to 31
# [0.18339768]
# Y 31
# 0.1833976833976834
# 31
# X 31 to 32
# [0.18339768]
# Y 32
# 0.15444015444015444
# 32
# X 32 to 33
# [0.15444015]
# Y 33
# 0.11196911196911194
# 33
# X 33 to 34
# [0.11196911]
# Y 34
# 0.08108108108108106
# 34
# X 34 to 35
# [0.08108108]
# Y 35
# 0.1196911196911197
# 35
# X 35 to 36
# [0.11969112]
# Y 36
# 0.12934362934362933
# 36
# X 36 to 37
# [0.12934363]
# Y 37
# 0.14671814671814673
# 37
# X 37 to 38
# [0.14671815]
# Y 38
# 0.17181467181467183
# 38
# X 38 to 39
# [0.17181467]
# Y 39
# 0.14864864864864866
# 39
# X 39 to 40
# [0.14864865]
# Y 40
# 0.1525096525096525
# 40
# X 40 to 41
# [0.15250965]
# Y 41
# 0.22007722007722005
# 41
# X 41 to 42
# [0.22007722]
# Y 42
# 0.24324324324324323
# 42
# X 42 to 43
# [0.24324324]
# Y 43
# 0.26640926640926643
# 43
# X 43 to 44
# [0.26640927]
# Y 44
# 0.20270270270270271
# 44
# X 44 to 45
# [0.2027027]
# Y 45
# 0.16795366795366792
# 45
# X 45 to 46
# [0.16795367]
# Y 46
# 0.13127413127413126
# 46
# X 46 to 47
# [0.13127413]
# Y 47
# 0.17374517374517376
# 47
# X 47 to 48
# [0.17374517]
# Y 48
# 0.1776061776061776
# 48
# X 48 to 49
# [0.17760618]
# Y 49
# 0.1776061776061776
# 49
# X 49 to 50
# [0.17760618]
# Y 50
# 0.25482625482625487
# 50
# X 50 to 51
# [0.25482625]
# Y 51
# 0.25289575289575295
# 51
# X 51 to 52
# [0.25289575]
# Y 52
# 0.2413127413127413
# 52
# X 52 to 53
# [0.24131274]
# Y 53
# 0.26833976833976836
# 53
# X 53 to 54
# [0.26833977]
# Y 54
# 0.3088803088803088
# 54
# X 54 to 55
# [0.30888031]
# Y 55
# 0.32432432432432434
# 55
# X 55 to 56
# [0.32432432]
# Y 56
# 0.2567567567567568
# 56
# X 56 to 57
# [0.25675676]
# Y 57
# 0.20656370656370657
# 57
# X 57 to 58
# [0.20656371]
# Y 58
# 0.14671814671814673
# 58
# X 58 to 59
# [0.14671815]
# Y 59
# 0.18725868725868725
# 59
# X 59 to 60
# [0.18725869]
# Y 60
# 0.19305019305019303
# 60
# X 60 to 61
# [0.19305019]
# Y 61
# 0.16216216216216214
# 61
# X 61 to 62
# [0.16216216]
# Y 62
# 0.25289575289575295
# 62
# X 62 to 63
# [0.25289575]
# Y 63
# 0.23745173745173745
# 63
# X 63 to 64
# [0.23745174]
# Y 64
# 0.2509652509652509
# 64
# X 64 to 65
# [0.25096525]
# Y 65
# 0.3088803088803088
# 65
# X 65 to 66
# [0.30888031]
# Y 66
# 0.38223938223938225
# 66
# X 66 to 67
# [0.38223938]
# Y 67
# 0.3648648648648648
# 67
# X 67 to 68
# [0.36486486]
# Y 68
# 0.2992277992277992
# 68
# X 68 to 69
# [0.2992278]
# Y 69
# 0.2413127413127413
# 69
# X 69 to 70
# [0.24131274]
# Y 70
# 0.1911196911196911
# 70
# X 70 to 71
# [0.19111969]
# Y 71
# 0.2413127413127413
# 71
# X 71 to 72
# [0.24131274]
# Y 72
# 0.26640926640926643
# 72
# X 72 to 73
# [0.26640927]
# Y 73
# 0.249034749034749
# 73
# X 73 to 74
# [0.24903475]
# Y 74
# 0.3146718146718146
# 74
# X 74 to 75
# [0.31467181]
# Y 75
# 0.31853281853281845
# 75
# X 75 to 76
# [0.31853282]
# Y 76
# 0.3204633204633204
# 76
# X 76 to 77
# [0.32046332]
# Y 77
# 0.4073359073359073
# 77
# X 77 to 78
# [0.40733591]
# Y 78
# 0.5019305019305019
# 78
# X 78 to 79
# [0.5019305]
# Y 79
# 0.46911196911196906
# 79
# X 79 to 80
# [0.46911197]
# Y 80
# 0.4015444015444015
# 80
# X 80 to 81
# [0.4015444]
# Y 81
# 0.3281853281853282
# 81
# X 81 to 82
# [0.32818533]
# Y 82
# 0.2567567567567568
# 82
# X 82 to 83
# [0.25675676]
# Y 83
# 0.3359073359073359
# 83
# X 83 to 84
# [0.33590734]
# Y 84
# 0.34749034749034746
# 84
# X 84 to 85
# [0.34749035]
# Y 85
# 0.333976833976834
# 85
# X 85 to 86
# [0.33397683]
# Y 86
# 0.41119691119691115
# 86
# X 86 to 87
# [0.41119691]
# Y 87
# 0.40347490347490345
# 87
# X 87 to 88
# [0.4034749]
# Y 88
# 0.4131274131274131
# 88
# X 88 to 89
# [0.41312741]
# Y 89
# 0.5212355212355212
# 89
# X 89 to 90
# [0.52123552]
# Y 90
# 0.5965250965250966
# 90
# X 90 to 91
# [0.5965251]
# Y 91
# 0.581081081081081
# 91
# X 91 to 92
# [0.58108108]
# Y 92
# 0.4845559845559845
# 92
# X 92 to 93
# [0.48455598]
# Y 93
# 0.38996138996138996
# 93
# X 93 to 94
# [0.38996139]
# Y 94
# 0.3223938223938224
# 94
# X 94 to 95
# [0.32239382]
# Y 95
# 0.38996138996138996
# 95
# X 95 to 96
# [0.38996139]
# Y 96
# 0.4073359073359073
# 96
# X 96 to 97
# [0.40733591]
# Y 97
# 0.3803088803088803
# 97
# X 97 to 98
# [0.38030888]
# Y 98
# 0.4864864864864865
# 44 1
# 0
# X 0 to 1
# [0.48455598]
# Y 1
# 0.6138996138996139
# 1
# X 1 to 2
# [0.61389961]
# Y 2
# 0.6969111969111969
# 2
# X 2 to 3
# [0.6969112]
# Y 3
# 0.7007722007722007
# 3
# X 3 to 4
# [0.7007722]
# Y 4
# 0.5791505791505791
# 4
# X 4 to 5
# [0.57915058]
# Y 5
# 0.46911196911196906
# 5
# X 5 to 6
# [0.46911197]
# Y 6
# 0.38803088803088803
# 6
# X 6 to 7
# [0.38803089]
# Y 7
# 0.44787644787644787
# 7
# X 7 to 8
# [0.44787645]
# Y 8
# 0.4555984555984556
# 8
# X 8 to 9
# [0.45559846]
# Y 9
# 0.4131274131274131
# 9
# X 9 to 10
# [0.41312741]
# Y 10
# 0.4980694980694981
# 10
# X 10 to 11
# [0.4980695]
# Y 11
# 0.471042471042471
# 11
# X 11 to 12
# [0.47104247]
# Y 12
# 0.5
# 12
# X 12 to 13
# [0.5]
# Y 13
# 0.6389961389961389
# 13
# X 13 to 14
# [0.63899614]
# Y 14
# 0.747104247104247
# 14
# X 14 to 15
# [0.74710425]
# Y 15
# 0.7741312741312741
# 15
# X 15 to 16
# [0.77413127]
# Y 16
# 0.5791505791505791
# 16
# X 16 to 17
# [0.57915058]
# Y 17
# 0.4922779922779923
# 17
# X 17 to 18
# [0.49227799]
# Y 18
# 0.39768339768339767
# 18
# X 18 to 19
# [0.3976834]
# Y 19
# 0.4498069498069498
# 19
# X 19 to 20
# [0.44980695]
# Y 20
# 0.4942084942084942
# 20
# X 20 to 21
# [0.49420849]
# Y 21
# 0.45945945945945943
# 21
# X 21 to 22
# [0.45945946]
# Y 22
# 0.583011583011583
# 22
# X 22 to 23
# [0.58301158]
# Y 23
# 0.5637065637065637
# 23
# X 23 to 24
# [0.56370656]
# Y 24
# 0.61003861003861
# 24
# X 24 to 25
# [0.61003861]
# Y 25
# 0.7104247104247104
# 25
# X 25 to 26
# [0.71042471]
# Y 26
# 0.8571428571428572
# 26
# X 26 to 27
# [0.85714286]
# Y 27
# 0.8783783783783783
# 27
# X 27 to 28
# [0.87837838]
# Y 28
# 0.693050193050193
# 28
# X 28 to 29
# [0.69305019]
# Y 29
# 0.5849420849420849
# 29
# X 29 to 30
# [0.58494208]
# Y 30
# 0.4980694980694981
# 30
# X 30 to 31
# [0.4980695]
# Y 31
# 0.581081081081081
# 31
# X 31 to 32
# [0.58108108]
# Y 32
# 0.6042471042471043
# 32
# X 32 to 33
# [0.6042471]
# Y 33
# 0.5540540540540541
# 33
# X 33 to 34
# [0.55405405]
# Y 34
# 0.6081081081081081
# 34
# X 34 to 35
# [0.60810811]
# Y 35
# 0.6891891891891891
# 35
# X 35 to 36
# [0.68918919]
# Y 36
# 0.7104247104247104
# 36
# X 36 to 37
# [0.71042471]
# Y 37
# 0.832046332046332
# 37
# X 37 to 38
# [0.83204633]
# Y 38
# 1.0
# 38
# X 38 to 39
# [1.]
# Y 39
# 0.9691119691119692
# 39
# X 39 to 40
# [0.96911197]
# Y 40
# 0.7799227799227799
# 40
# X 40 to 41
# [0.77992278]
# Y 41
# 0.6891891891891891
# 41
# X 41 to 42
# [0.68918919]
# Y 42
# 0.5521235521235521

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_train.shape)
print(X_test.shape)
# Out:
# (98, 1, 1)
# (42, 1, 1)

# %%
batch_size = 1
model = Sequential()
model.add(LSTM(4, batch_input_shape=(batch_size, look_back, 1), stateful=True))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X_train, y_train, epochs=100, batch_size=batch_size, verbose=2, shuffle=True)
# Out:
# Epoch 1/100
#  - 3s - loss: 0.0552
# Epoch 2/100
#  - 0s - loss: 0.0209
# Epoch 3/100
#  - 0s - loss: 0.0197
# Epoch 4/100
#  - 0s - loss: 0.0188
# Epoch 5/100
#  - 0s - loss: 0.0177
# Epoch 6/100
#  - 0s - loss: 0.0168
# Epoch 7/100
#  - 0s - loss: 0.0164
# Epoch 8/100
#  - 0s - loss: 0.0158
# Epoch 9/100
#  - 0s - loss: 0.0151
# Epoch 10/100
#  - 0s - loss: 0.0139
# Epoch 11/100
#  - 0s - loss: 0.0136
# Epoch 12/100
#  - 0s - loss: 0.0126
# Epoch 13/100
#  - 0s - loss: 0.0120
# Epoch 14/100
#  - 0s - loss: 0.0109
# Epoch 15/100
#  - 0s - loss: 0.0104
# Epoch 16/100
#  - 0s - loss: 0.0094
# Epoch 17/100
#  - 0s - loss: 0.0082
# Epoch 18/100
#  - 0s - loss: 0.0086
# Epoch 19/100
#  - 0s - loss: 0.0091
# Epoch 20/100
#  - 0s - loss: 0.0071
# Epoch 21/100
#  - 0s - loss: 0.0061
# Epoch 22/100
#  - 0s - loss: 0.0062
# Epoch 23/100
#  - 0s - loss: 0.0053
# Epoch 24/100
#  - 0s - loss: 0.0054
# Epoch 25/100
#  - 0s - loss: 0.0042
# Epoch 26/100
#  - 0s - loss: 0.0042
# Epoch 27/100
#  - 0s - loss: 0.0045
# Epoch 28/100
#  - 0s - loss: 0.0038
# Epoch 29/100
#  - 0s - loss: 0.0037
# Epoch 30/100
#  - 0s - loss: 0.0034
# Epoch 31/100
#  - 0s - loss: 0.0029
# Epoch 32/100
#  - 0s - loss: 0.0024
# Epoch 33/100
#  - 0s - loss: 0.0030
# Epoch 34/100
#  - 0s - loss: 0.0027
# Epoch 35/100
#  - 0s - loss: 0.0024
# Epoch 36/100
#  - 0s - loss: 0.0027
# Epoch 37/100
#  - 0s - loss: 0.0024
# Epoch 38/100
#  - 0s - loss: 0.0025
# Epoch 39/100
#  - 0s - loss: 0.0024
# Epoch 40/100
#  - 0s - loss: 0.0024
# Epoch 41/100
#  - 0s - loss: 0.0024
# Epoch 42/100
#  - 0s - loss: 0.0026
# Epoch 43/100
#  - 0s - loss: 0.0026
# Epoch 44/100
#  - 0s - loss: 0.0024
# Epoch 45/100
#  - 0s - loss: 0.0026
# Epoch 46/100
#  - 0s - loss: 0.0022
# Epoch 47/100
#  - 0s - loss: 0.0022
# Epoch 48/100
#  - 0s - loss: 0.0023
# Epoch 49/100
#  - 0s - loss: 0.0024
# Epoch 50/100
#  - 0s - loss: 0.0022
# Epoch 51/100
#  - 0s - loss: 0.0022
# Epoch 52/100
#  - 0s - loss: 0.0025
# Epoch 53/100
#  - 0s - loss: 0.0024
# Epoch 54/100
#  - 0s - loss: 0.0021
# Epoch 55/100
#  - 0s - loss: 0.0020
# Epoch 56/100
#  - 0s - loss: 0.0021
# Epoch 57/100
#  - 0s - loss: 0.0023
# Epoch 58/100
#  - 0s - loss: 0.0022
# Epoch 59/100
#  - 0s - loss: 0.0024
# Epoch 60/100
#  - 0s - loss: 0.0021
# Epoch 61/100
#  - 0s - loss: 0.0024
# Epoch 62/100
#  - 0s - loss: 0.0021
# Epoch 63/100
#  - 0s - loss: 0.0022
# Epoch 64/100
#  - 0s - loss: 0.0024
# Epoch 65/100
#  - 0s - loss: 0.0022
# Epoch 66/100
#  - 0s - loss: 0.0022
# Epoch 67/100
#  - 0s - loss: 0.0021
# Epoch 68/100
#  - 0s - loss: 0.0024
# Epoch 69/100
#  - 0s - loss: 0.0023
# Epoch 70/100
#  - 0s - loss: 0.0022
# Epoch 71/100
#  - 0s - loss: 0.0021
# Epoch 72/100
#  - 0s - loss: 0.0022
# Epoch 73/100
#  - 0s - loss: 0.0022
# Epoch 74/100
#  - 0s - loss: 0.0022
# Epoch 75/100
#  - 0s - loss: 0.0021
# Epoch 76/100
#  - 0s - loss: 0.0020
# Epoch 77/100
#  - 0s - loss: 0.0021
# Epoch 78/100
#  - 0s - loss: 0.0022
# Epoch 79/100
#  - 0s - loss: 0.0020
# Epoch 80/100
#  - 0s - loss: 0.0022
# Epoch 81/100
#  - 0s - loss: 0.0022
# Epoch 82/100
#  - 0s - loss: 0.0022
# Epoch 83/100
#  - 0s - loss: 0.0020
# Epoch 84/100
#  - 0s - loss: 0.0021
# Epoch 85/100
#  - 0s - loss: 0.0021
# Epoch 86/100
#  - 0s - loss: 0.0021
# Epoch 87/100
#  - 0s - loss: 0.0022
# Epoch 88/100
#  - 0s - loss: 0.0021
# Epoch 89/100
#  - 0s - loss: 0.0020
# Epoch 90/100
#  - 0s - loss: 0.0022
# Epoch 91/100
#  - 0s - loss: 0.0022
# Epoch 92/100
#  - 0s - loss: 0.0020
# Epoch 93/100
#  - 0s - loss: 0.0021
# Epoch 94/100
#  - 0s - loss: 0.0022
# Epoch 95/100
#  - 0s - loss: 0.0022
# Epoch 96/100
#  - 0s - loss: 0.0022
# Epoch 97/100
#  - 0s - loss: 0.0021
# Epoch 98/100
#  - 0s - loss: 0.0022
# Epoch 99/100
#  - 0s - loss: 0.0021
# Epoch 100/100
#  - 0s - loss: 0.0021

# %%
import math
from sklearn.metrics import mean_squared_error

trainPredict = model.predict(X_train, batch_size=batch_size)
model.reset_states()

testPredict = model.predict(X_test, batch_size=batch_size)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
y_train = scaler.inverse_transform([y_train])
testPredict = scaler.inverse_transform(testPredict)
y_test = scaler.inverse_transform([y_test])
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(y_train[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(y_test[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 23796.95 RMSE
# Test Score: 53055.86 RMSE

# %%
trainPredictPlot = np.empty_like(scaled)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(scaled)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(scaled)-1, :] = testPredict
# plot baseline and predictions
plt.figure(figsize=(20,10))
plt.plot(scaler.inverse_transform(scaled))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
